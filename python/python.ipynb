# %% [markdown]
# ###1. Lists

# %% [markdown]
# - Ordered (index-based access)
# - Mutable (can add/remove/update)
# - Allows duplicates
# - Supports mixed data types
# - Uses square brackets []

# %% [markdown]
# Syntax

# %%
my_list = [10, 20, 30, "energy", 45.5]
print(my_list)

# %% [markdown]
# Accessing elements

# %%
my_list = [10, 20, 30]
print(my_list[1])

# %% [markdown]
# Modifying

# %%
my_list[1] = 200
print(my_list)

# %% [markdown]
# Adding

# %%
my_list.append(40)
print(my_list)

# %% [markdown]
# Removing

# %%
my_list.remove(10)
print(my_list)

# %% [markdown]
# ###2. Tuples

# %% [markdown]
# - Ordered
# - Immutable (cannot modify after creation)
# - Allows duplicates
# - Supports mixed data types
# - Uses parentheses ()

# %% [markdown]
# Accessing elements

# %%
my_tuple = (10, 20, 30)
print(my_tuple[1])     # 20

# %% [markdown]
# Attempt to modify

# %%
my_tuple[1] = 200
# Error: 'tuple' object does not support item assignment

# %% [markdown]
# ###3. Dictionary

# %% [markdown]
# - Unordered
# - Mutable collection of key-value pairs
# - Keys must be uniuqe and immutable

# %% [markdown]
# Method 1: Using curly braces {}

# %%
student = {
    "name": "Bharath",
    "age": 28,
    "role": "Data Engineer"
}

print(student)

# %% [markdown]
# Method 2: Using dict() constructor

# %%
student = dict(name="Bharath", age=28, role="Data Engineer")
print(student)

# %% [markdown]
# Method 3: Empty dictionary

# %%
data = {}
print(data)

# %% [markdown]
# Access using key (Recommended)

# %%
print(student["name"])

# %% [markdown]
# Using get() method (Safe way)

# %%
print(student.get("age"))

# %% [markdown]
# With default value

# %%
print(student.get("salary", "Not Available"))

# %% [markdown]
# Modifying Values

# %%
student["age"] = 29
print(student["age"])

# %% [markdown]
# Adding New Key-Value Pair

# %%
student["location"] = "India"
print(student["location"])

# %% [markdown]
# Changing the existing key data type

# %%
student["Age"] = "Twenty Nine"
print(student["Age"])

# %% [markdown]
# ###4. List Comprehension

# %% [markdown]
# Traditional approach

# %%
squares = []
for i in range(5):
    squares.append(i * i)

print(squares)
# [0, 1, 4, 9, 16]

# %% [markdown]
# List comprehension

# %%
squares = [i * i for i in range(5)]
print(squares)
# [0, 1, 4, 9, 16]

# %% [markdown]
# List comprehension - With Condition

# %%
evens = [i for i in range(10) if i % 2 == 0]
print(evens)
# [0, 2, 4, 6, 8]

# %% [markdown]
# List comprehension - Transforming Data

# %%
names = ["energy", "data", "python"]

upper_names = [name.upper() for name in names]
print(upper_names)
# ['ENERGY', 'DATA', 'PYTHON']

# %% [markdown]
# List comprehension - Practical (Data Engineering context)

# %%
mw_values = [1.2, 0.8, 3.5]

kw_values = [mw * 1000 for mw in mw_values]
print(kw_values)
# [1200, 800, 3500]

# %% [markdown]
# List comprehension - Nested List Comprehension

# %%
matrix = [[1, 2], [3, 4], [5, 6]]

flat = [num for row in matrix for num in row]
print(flat)
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ###5. Set

# %% [markdown]
# - Unordered
# - Mutable
# - Automatically removes duplicate values

# %% [markdown]
# Creating a Set

# %%
numbers = {1, 2, 3, 4}
print(numbers)
# {1, 2, 3, 4}

# %% [markdown]
# From a list (removes duplicates automatically)

# %%
nums = [1, 2, 2, 3, 4, 4]
unique_nums = set(nums)
print(unique_nums)
# {1, 2, 3, 4}

# %% [markdown]
# Empty set (important) - creates an empty dictionary, not a set.

# %%
empty_set = set()   # Correct

# %% [markdown]
# Adding and Removing Elements

# %%
data = {10, 20, 30}

data.add(40)
print(data)

data.remove(20)
print(data)

# %% [markdown]
# Set Operations (Very Important)

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a | b)
# {1, 2, 3, 4, 5}

# %% [markdown]
# Intersection (Common elements)

# %%
print(a & b)
# {3}

# %% [markdown]
# Difference

# %%
print(a - b)
# {1, 2}

# %% [markdown]
# Practical Example (Data Engineering Context)

# %%
user_ids = [101, 102, 103, 101, 104, 102]
unique_users = set(user_ids)

print(unique_users)
# {101, 102, 103, 104}

# %% [markdown]
# ###6. Reverse a String — Write a function to reverse a string in Python.

# %%
def reverse_string(s):
    print(s)
    reversed_str = ""
    print(type(reversed_str))
    for char in s:
        print(char)
        reversed_str = char + reversed_str
        print(reversed_str )
    return reversed_str

print(reverse_string("Python"))

# %% [markdown]
# ###7. Find Duplicates in a List — Write a function to find duplicates in a list and return them as a set

# %%
def find_duplicates(lst):
    seen = set()
    duplicates = set()
    
    for item in lst:
        if item in seen:
            duplicates.add(item)
        else:
            seen.add(item)
    
    return duplicates

# Example
numbers = [1, 2, 3, 4, 2, 5, 1, 6]
print(find_duplicates(numbers))
# Output: {1, 2}

# %% [markdown]
# ###8. Implement a Stack — Implement a stack data structure in Python.

# %% [markdown]
# A stack is a linear data structure that follows LIFO (Last In, First Out) — the last element pushed is the first one popped.

# %%
class Stack:
    def __init__(self):
        self.items = []

    # Push element onto stack
    def push(self, item):
        self.items.append(item)

    # Pop element from stack
    def pop(self):
        if self.is_empty():
            return "Stack is empty"
        return self.items.pop()

    # Peek top element
    def peek(self):
        if self.is_empty():
            return "Stack is empty"
        return self.items[-1]

    # Check if stack is empty
    def is_empty(self):
        return len(self.items) == 0

    # Get stack size
    def size(self):
        return len(self.items)

    # Display stack
    def display(self):
        return self.items

s = Stack()

s.push(10)
s.push(20)
s.push(30)

print("Stack:", s.display())
print("Top element:", s.peek())

print("Popped:", s.pop())
print("After pop:", s.display())

print("Is empty?", s.is_empty())
print("Size:", s.size())

# %% [markdown]
# ###9. Check Palindrome — Write a function to check if a given string is a palindrome.

# %%
def is_palindrome(s):
    s = s.lower().replace(" ", "")
    left, right = 0, len(s) - 1

    while left < right:
        if s[left] != s[right]:
            return False
        left += 1
        right -= 1

    return True

print(is_palindrome("A man, a plan, a canal: Panama"))  # True
print(is_palindrome("No lemon, no melon"))              # True
print(is_palindrome("Hello World"))                     # False

# %% [markdown]
# ###10. Find Missing Number — Given a list of integers from 1 to n, with one number missing, write a function to find the missing number.

# %%
def find_missing(nums):
    n = len(nums) + 1
    expected_sum = n * (n + 1) // 2
    actual_sum = sum(nums)
    return expected_sum - actual_sum

nums = [1, 2, 4, 5]
print(find_missing(nums))   # 3

# %% [markdown]
# ###11. Count Vowels and Consonants — Write a function to count the number of vowels and consonants in a given string.

# %%
def count_vowels_consonants(s):
    vowels = "aeiou"
    vowel_count = 0
    consonant_count = 0

    for char in s.lower():
        if char.isalpha():          # consider only letters
            if char in vowels:
                vowel_count += 1
            else:
                consonant_count += 1

    return vowel_count, consonant_count

text = "Hello World"
vowels, consonants = count_vowels_consonants(text)

print("Vowels:", vowels)        # 3
print("Consonants:", consonants)  # 7

# %% [markdown]
# ###12. Merge Sorted Lists — Write a function to merge two sorted lists into a single sorted list.

# %%
def merge_sorted_lists(list1, list2):
    i, j = 0, 0
    merged = []

    while i < len(list1) and j < len(list2):
        if list1[i] <= list2[j]:
            merged.append(list1[i])
            i += 1
        else:
            merged.append(list2[j])
            j += 1

    # Add remaining elements
    merged.extend(list1[i:])
    merged.extend(list2[j:])

    return merged

l1 = [1, 3, 5, 7]
l2 = [2, 4, 6, 8]

print(merge_sorted_lists(l1, l2))

# %% [markdown]
# ###13. Implement a Queue — Implement a queue data structure in Python.

# %% [markdown]
# A queue removes elements in the order they were inserted.

# %%
class Queue:
    def __init__(self):
        self.items = []

    # Enqueue (add to rear)
    def enqueue(self, item):
        self.items.append(item)

    # Dequeue (remove from front)
    def dequeue(self):
        if self.is_empty():
            return "Queue is empty"
        return self.items.pop(0)

    # Peek front element
    def peek(self):
        if self.is_empty():
            return "Queue is empty"
        return self.items[0]

    # Check if empty
    def is_empty(self):
        return len(self.items) == 0

    # Get size
    def size(self):
        return len(self.items)

    # Display queue
    def display(self):
        return self.items
    
q = Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

print("Queue:", q.display())
print("Front:", q.peek())

print("Dequeued:", q.dequeue())
print("After dequeue:", q.display())

# %% [markdown]
# ###14. Find Maximum Subarray Sum — Write a function to find the maximum sum of a contiguous subarray within a one-dimensional array of numbers.

# %%
def max_subarray_sum(nums):
    max_sum = nums[0]
    current_sum = nums[0]

    for num in nums[1:]:
        current_sum = max(num, current_sum + num)
        max_sum = max(max_sum, current_sum)

    return max_sum

arr = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
print(max_subarray_sum(arr))

# %% [markdown]
# ###15. How to find the maximum value in a list without using the max function?

# %%
def find_max(nums):
    maximum = nums[0]          # assume first element is max

    for num in nums:
        if num > maximum:
            maximum = num

    return maximum

numbers = [3, 7, 2, 9, 5]
print(find_max(numbers))   # 9

# %% [markdown]
# ###16. Write a program to check if a number is a prime number.

# %%
def is_prime(n):
    if n <= 1:
        return False

    for i in range(2, n):
        if n % i == 0:
            return False

    return True

print(is_prime(7))   # True
print(is_prime(10))  # False

# %% [markdown]
# ###17. How to find unique and duplicate elements from a list?

# %%
def find_unique_duplicates(nums):
    seen = set()
    duplicates = set()

    for num in nums:
        if num in seen:
            duplicates.add(num)
        else:
            seen.add(num)

    unique = seen - duplicates
    return list(unique), list(duplicates)

nums = [1, 2, 3, 2, 4, 5, 1, 6]
unique, duplicates = find_unique_duplicates(nums)
print("Unique:", unique)         # [3,4,5,6]
print("Duplicates:", duplicates) # [1,2]

# %% [markdown]
# ###18. How to remove duplicates from a list?

# %%
def remove_duplicates(nums):
    return list(set(nums))

nums = [1, 2, 2, 3, 4, 1, 5]
print(remove_duplicates(nums))
# Output order may vary

# %% [markdown]
# ###19. When to use append and when to use extend in Python?

# %% [markdown]
# Use append when:
# - Adding single value
# - Building stacks
# - Keeping nested structure

# %%
lst = [1, 2, 3]
lst.append(4)
# [1, 2, 3, 4]
print(lst)

lst = [1, 2, 3]
lst.append([4, 5])
# [1, 2, 3, [4, 5]]
print(lst)

# %% [markdown]
# Use extend when:
#   - Merging lists
#   - Adding many values
#   - Flattening one level

# %%
lst = [1, 2, 3]
lst.extend([4, 5])
# [1, 2, 3, 4, 5]
print(lst)

lst = [1, 2]
lst.extend("ab")
# [1, 2, 'a', 'b']
print(lst)

# %% [markdown]
# ###20. Write a program to generate Fibonacci series up to n.

# %%
def fibonacci(n):
    a, b = 0, 1

    for _ in range(n):
        print(a, end=" ")
        a, b = b, a + b

fibonacci(10)

# %% [markdown]
# ###21. How to convert a list into a dictionary?

# %%
pairs = [("a", 1), ("b", 2), ("c", 3)]

result = dict(pairs)
print(result)

# %%
keys = ["a", "b", "c"]
values = [1, 2, 3]

result = dict(zip(keys, values))
print(result)

# %%
lst = ["apple", "banana", "cherry"]

result = {i: lst[i] for i in range(len(lst))}
print(result)

# %%
keys = ["a", "b", "c"]

result = dict.fromkeys(keys, 0)
print(result)

# %% [markdown]
# ###22. Write a program to check if an array is sorted.

# %%
def is_sorted(arr):
    for i in range(len(arr) - 1):
        if arr[i] > arr[i + 1]:
            return False
    return True

print(is_sorted([1, 2, 3, 4]))   # True
print(is_sorted([1, 3, 2, 4]))   # False

# %% [markdown]
# ###23. What is the difference between deepcopy and copy in Python?

# %% [markdown]
# Shallow copy - Creates a new outer object, but inner objects are still referenced (shared).

# %%
import copy

original = [[1, 2], [3, 4]]
shallow = copy.copy(original)

shallow[0][0] = 100

print(original)   # [[100, 2], [3, 4]]
print(shallow)    # [[100, 2], [3, 4]]

# %% [markdown]
# Deep Copy - Creates a new outer object and recursively copies all nested objects.

# %%
import copy

original = [[1, 2], [3, 4]]
deep = copy.deepcopy(original)

deep[0][0] = 100

print(original)   # [[1, 2], [3, 4]]
print(deep)       # [[100, 2], [3, 4]]

# %% [markdown]
# ###24.How would you handle missing data in a dataset using Python?

# %% [markdown]
# 1. Fill with Constant
# 2. Fill with Mean / Median (Numerical Columns)
# 3. Fill with Mode (Categorical Columns)
# 4. Interpolation (Numerical Data) - Estimates missing values using surrounding values.

# %% [markdown]
# ###25. What is a generator in Python? How is it different from a list?

# %% [markdown]
# - A generator is a special type of function that returns an iterator and produces values one at a time, using the yield keyword instead of return.
#
# - It generates values lazily (only when needed), which makes it memory efficient.

# %% [markdown]
# Example 1: Generator Function

# %%
def count_up_to(n):
    for i in range(1, n + 1):
        yield i   # produces one value at a time

gen = count_up_to(5)

print(next(gen))  # 1
print(next(gen))  # 2
print(next(gen))  # 3

# %% [markdown]
# Example 2: List Version (Normal Function)

# %%
def count_up_to_list(n):
    result = []
    for i in range(1, n + 1):
        result.append(i)
    return result

lst = count_up_to_list(5)
print(lst)  # [1, 2, 3, 4, 5]

# %% [markdown]
# ###26. Explain the use of *args and **kwargs.

# %% [markdown]
# - args is pronounced like “arghz” (rhymes with “cars”)
# - kwargs is pronounced “kwarghz” (like “quargs” or “k-wargs”)

# %% [markdown]
# *args (Non-keyword Variable Arguments)

# %% [markdown]
# - Collects multiple positional arguments
# - Stored as a tuple
# - Function works with any number of inputs

# %%
def add_numbers(*args):
    total = 0
    for num in args:
        total += num
    return total

print(add_numbers(1, 2, 3))        # 6
print(add_numbers(10, 20, 30, 40)) # 100

# %% [markdown]
# **kwargs (Keyword Variable Arguments)

# %% [markdown]
# - Collects multiple keyword arguments
# - Stored as a dictionary
# - Dynamic named parameters

# %%
def print_details(**kwargs):
    for key, value in kwargs.items():
        print(f"{key} = {value}")

print_details(name="Bharath", role="Data Engineer", experience=5)

# %% [markdown]
# ###27. How to remove empty strings from a list?

# %%
data = ["apple", "", "banana", "", "cherry"]

cleaned = [x for x in data if x != ""]
print(cleaned)

# %% [markdown]
# ###28. Write a program to find the common elements in two lists.

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

common = list(set(list1) & set(list2))

print(common)

# %%
list1 = [1, 2, 2, 3, 4]
list2 = [2, 2, 4, 6]

common = [x for x in list1 if x in list2]

print(common)

# %% [markdown]
# ###29. How to use map, filter, and reduce in Python?

# %% [markdown]
# map() – Transform Data
# - Applies a function to every element in an iterable.

# %%
numbers = [1, 2, 3, 4]

squares = list(map(lambda x: x**2, numbers))

print(squares)

# %% [markdown]
# filter() – Filter Data
# - Filters elements based on a condition.

# %%
numbers = [1, 2, 3, 4, 5, 6]

evens = list(filter(lambda x: x % 2 == 0, numbers))

print(evens)

# %% [markdown]
# reduce() – Reduce to Single Value
# - Performs cumulative computation and reduces iterable to one value.
# - Must import from functools.
# - Aggregation

# %%
from functools import reduce

numbers = [1, 2, 3, 4]

product = reduce(lambda x, y: x * y, numbers)

print(product)

# %% [markdown]
# ###30. Write a program to implement a queue using a list.

# %%
class Queue:
    def __init__(self):
        self.queue = []

    # Enqueue (Insert at rear)
    def enqueue(self, item):
        self.queue.append(item)
        print(f"Enqueued: {item}")

    # Dequeue (Remove from front)
    def dequeue(self):
        if self.is_empty():
            return "Queue is empty"
        return self.queue.pop(0)

    # Peek (Front element)
    def peek(self):
        if self.is_empty():
            return "Queue is empty"
        return self.queue[0]

    # Check if empty
    def is_empty(self):
        return len(self.queue) == 0

    # Size of queue
    def size(self):
        return len(self.queue)
    
q = Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

print("Dequeued:", q.dequeue())  # 10
print("Front:", q.peek())        # 20
print("Size:", q.size())

# %% [markdown]
# ###31. How to use groupby and pivot_table in Pandas?

# %%
import pandas as pd

data = {
    "Department": ["IT", "IT", "HR", "HR", "Finance"],
    "Employee": ["A", "B", "C", "D", "E"],
    "Salary": [50000, 60000, 45000, 47000, 70000]
}

df = pd.DataFrame(data)
print(df)

result = df.groupby("Department")["Salary"].sum()
print(result)
